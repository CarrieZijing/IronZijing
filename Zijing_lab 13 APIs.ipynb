# %%
#Challenge1 Get a Picture
import requests
#get data
r=requests.get('https://xkcd.com/')
#check status
r.status_code
# Out:
# 200

# %%
#check the headers
r.headers
# Out:
# {'Connection': 'keep-alive', 'Content-Length': '2643', 'Server': 'nginx', 'Content-Type': 'text/html; charset=UTF-8', 'Last-Modified': 'Mon, 06 Dec 2021 05:00:03 GMT', 'ETag': 'W/"61ad98d3-1a93"', 'Expires': 'Mon, 06 Dec 2021 05:06:00 GMT', 'Cache-Control': 'max-age=300', 'Content-Encoding': 'gzip', 'Accept-Ranges': 'bytes', 'Date': 'Mon, 06 Dec 2021 13:10:31 GMT', 'Via': '1.1 varnish', 'Age': '84', 'X-Served-By': 'cache-cdg20770-CDG', 'X-Cache': 'HIT', 'X-Cache-Hits': '1', 'X-Timer': 'S1638796231.386310,VS0,VE1', 'Vary': 'Accept-Encoding'}

# %%
#check the headers "Expires" value
r.headers['Expires']
# Out:
# 'Mon, 06 Dec 2021 05:06:00 GMT'

# %%
#Provide all HTML codes
r.text
# Out:
# '<!DOCTYPE html>\n<html>\n<head>\n<link rel="stylesheet" type="text/css" href="/s/7d94e0.css" title="Default"/>\n<title>xkcd: Webb</title>\n<meta http-equiv="X-UA-Compatible" content="IE=edge"/>\n<link rel="shortcut icon" href="/s/919f27.ico" type="image/x-icon"/>\n<link rel="icon" href="/s/919f27.ico" type="image/x-icon"/>\n<link rel="alternate" type="application/atom+xml" title="Atom 1.0" href="/atom.xml"/>\n<link rel="alternate" type="application/rss+xml" title="RSS 2.0" href="/rss.xml"/>\n<script type="text/javascript" src="/s/b66ed7.js" async></script>\n<script type="text/javascript" src="/s/1b9456.js" async></script>\n\n<meta property="og:site_name" content="xkcd">\n\n<meta property="og:title" content="Webb">\n<meta property="og:url" content="https://xkcd.com/2550/">\n<meta property="og:image" content="https://imgs.xkcd.com/comics/webb_2x.png">\n<meta name="twitter:card" content="summary_large_image">\n\n</head>\n<body>\n<div id="topContainer">\n<div id="topLeft">\n<ul>\n<li><a href="/archive">Archive</a></li>\n<li><a href="https://what-if.xkcd.com">What If?</a></li>\n<li><a href="https://blag.xkcd.com">Blag</a></li>\n<li><a href="/how-to/">How To</a></li>\n<li><a href="https://store.xkcd.com/">Store</a></li>\n<li><a rel="author" href="/about">About</a></li>\n<li><a href="/atom.xml">Feed</a> &bull; <a href="/newsletter/">Email</a></li>\n<li><a href="https://twitter.com/xkcd/">TW</a> &bull; <a href="https://www.facebook.com/TheXKCD/">FB</a> &bull; <a href="https://www.instagram.com/xkcd/">IG</a></li>\n</ul>\n</div>\n<div id="topRight">\n<div id="masthead">\n<span><a href="/"><img src="/s/0b7742.png" alt="xkcd.com logo" height="83" width="185"/></a></span>\n<span id="slogan">A webcomic of romance,<br/> sarcasm, math, and language.</span>\n</div>\n<div id="news">\n<div id="xkcdBanner"><a href="https://blacklivesmatter.com/"><img border=0 src="//imgs.xkcd.com/news/blm.png"></a></div>\n\n</div>\n</div>\n<div id="bgLeft" class="bg box"></div>\n<div id="bgRight" class="bg box"></div>\n</div>\n<div id="middleContainer" class="box">\n\n<div id="ctitle">Webb</div>\n<ul class="comicNav">\n<li><a href="/1/">|&lt;</a></li>\n<li><a rel="prev" href="/2549/" accesskey="p">&lt; Prev</a></li>\n<li><a href="//c.xkcd.com/random/comic/">Random</a></li>\n<li><a rel="next" href="#" accesskey="n">Next &gt;</a></li>\n<li><a href="/">&gt;|</a></li>\n</ul>\n<div id="comic">\n<img src="//imgs.xkcd.com/comics/webb.png" title="Each one contains a chocolate shaped like a famous spacecraft and, for the later numbers, a pamphlet on managing anxiety." alt="Webb" srcset="//imgs.xkcd.com/comics/webb_2x.png 2x" style="image-orientation:none" />\n</div>\n<ul class="comicNav">\n<li><a href="/1/">|&lt;</a></li>\n<li><a rel="prev" href="/2549/" accesskey="p">&lt; Prev</a></li>\n<li><a href="//c.xkcd.com/random/comic/">Random</a></li>\n<li><a rel="next" href="#" accesskey="n">Next &gt;</a></li>\n<li><a href="/">&gt;|</a></li>\n</ul>\n<br />\nPermanent link to this comic: <a href="https://xkcd.com/2550">https://xkcd.com/2550/</a><br />\nImage URL (for hotlinking/embedding): <a href= "https://imgs.xkcd.com/comics/webb.png">https://imgs.xkcd.com/comics/webb.png</a>\n\n<div id="transcript" style="display: none"></div>\n</div>\n<div id="bottom" class="box">\n<img src="//imgs.xkcd.com/s/a899e84.jpg" width="520" height="100" alt="Selected Comics" usemap="#comicmap"/>\n<map id="comicmap" name="comicmap">\n<area shape="rect" coords="0,0,100,100" href="/150/" alt="Grownups"/>\n<area shape="rect" coords="104,0,204,100" href="/730/" alt="Circuit Diagram"/>\n<area shape="rect" coords="208,0,308,100" href="/162/" alt="Angular Momentum"/>\n<area shape="rect" coords="312,0,412,100" href="/688/" alt="Self-Description"/>\n<area shape="rect" coords="416,0,520,100" href="/556/" alt="Alternative Energy Revolution"/>\n</map>\n<br />\n<a href="//xkcd.com/1732/"><img border=0 src="//imgs.xkcd.com/s/temperature.png" width="520" height="100" alt="Earth temperature timeline"></a>\n<br />\ ...

# %%
#Get it via API
receive = requests.get('https://imgs.xkcd.com/comics/tv_problems_2x.png')

#Save it to your computer
with open (r'/Users/carrie/Downloads/image_lab13.png','wb') as f:
    f.write(receive.content)

# %%
#Challenge 2: Get a password
r=requests.get('https://httpbin.org/get')
r.headers
# Out:
# {'Date': 'Mon, 06 Dec 2021 13:31:29 GMT', 'Content-Type': 'application/json', 'Content-Length': '309', 'Connection': 'keep-alive', 'Server': 'gunicorn/19.9.0', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true'}

# %%
#get information from the website => use 'get'
ploads={'things':2,'total':25}
r=requests.get('https://httpbin.org/get',params=ploads)

print(r.text)
print(r.url)
#args:argument, when you add element inside, it turns from parameters to arguments
# Out:
# {
#   "args": {
#     "things": "2",
#     "total": "25"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.25.1",
#     "X-Amzn-Trace-Id": "Root=1-61ae7161-5876514b706f34b77eec0a86"
#   },
#   "origin": "176.158.162.117",
#   "url": "https://httpbin.org/get?things=2&total=25"
# }
#
# https://httpbin.org/get?things=2&total=25

# %%
#send information to the website => so use 'post'
ploads={'username':'Zijing','password':'Carrie'}
r=requests.post('https://httpbin.org/post',data=ploads)

print(r.text)
# Out:
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "password": "Carrie",
#     "username": "Zijing"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "31",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.25.1",
#     "X-Amzn-Trace-Id": "Root=1-61ae1388-77d2ca360bf6fd1d735e591b"
#   },
#   "json": null,
#   "origin": "195.134.167.217",
#   "url": "https://httpbin.org/post"
# }

# %%
#Export username and password as dictionary
ploads={'username':'Zijing','password':'Carrie'}
r=requests.post('https://httpbin.org/post',data=ploads)

#turn the result of request.post (<class 'requests.models.Response'>) into => <class 'dict'>
a=r.json()
print(a['form'])
# Out:
# {'password': 'Carrie', 'username': 'Zijing'}

# %%
#Challenge 3: Hidden Cold Joke

r1=requests.get('https://github.com/ironhack-datalabs/scavenger')
print(r1.status_code)
#print(r1.text)

a1=r1.json()
d1 = pd.DataFrame(a1)

#print(type(r1))
#print(a1)
# Out:
# 200
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-216-ed9a6db41c41> in <module>
#       5 #print(r1.text)
#       6
# ----> 7 a1=r1.json()
#       8 d1 = pd.DataFrame(a1)
#       9
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/models.py in json(self, **kwargs)
#     898                     # used.
#     899                     pass
# --> 900         return complexjson.loads(self.text, **kwargs)
#     901
#     902     @property
#
# ~/opt/anaconda3/lib/python3.8/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# ~/opt/anaconda3/lib/python3.8/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~/opt/anaconda3/lib/python3.8/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 7 column 1 (char 6)

# %%
#Challenge fork
#https://api.github.com/users/Ironhack/repos

import json
import requests

#Use the get method to send a request to the JSONPlaceholder API
response = requests.get('https://api.github.com/users/Ironhack/repos')

print(response.status_code)

#print(response.text)

results = response.json()
#print(results)

data = pd.DataFrame(results)
data
#flattened_data = pd.json_normalize(results)
#flattened_data
# Out:
# <class 'requests.models.Response'>
# 200
#            id                           node_id  \
# 0    75170096  MDEwOlJlcG9zaXRvcnk3NTE3MDA5Ng==
# 1   197550983  MDEwOlJlcG9zaXRvcnkxOTc1NTA5ODM=
# 2    57225749  MDEwOlJlcG9zaXRvcnk1NzIyNTc0OQ==
# 3    56848097  MDEwOlJlcG9zaXRvcnk1Njg0ODA5Nw==
# 4   122097049  MDEwOlJlcG9zaXRvcnkxMjIwOTcwNDk=
# 5    96100950  MDEwOlJlcG9zaXRvcnk5NjEwMDk1MA==
# 6    62580111  MDEwOlJlcG9zaXRvcnk2MjU4MDExMQ==
# 7   150108250  MDEwOlJlcG9zaXRvcnkxNTAxMDgyNTA=
# 8    44265416  MDEwOlJlcG9zaXRvcnk0NDI2NTQxNg==
# 9    56841990  MDEwOlJlcG9zaXRvcnk1Njg0MTk5MA==
# 10  134574029  MDEwOlJlcG9zaXRvcnkxMzQ1NzQwMjk=
# 11  115990443  MDEwOlJlcG9zaXRvcnkxMTU5OTA0NDM=
# 12   96104549  MDEwOlJlcG9zaXRvcnk5NjEwNDU0OQ==
# 13   86328286  MDEwOlJlcG9zaXRvcnk4NjMyODI4Ng==
# 14   34860891  MDEwOlJlcG9zaXRvcnkzNDg2MDg5MQ==
# 15  139946618  MDEwOlJlcG9zaXRvcnkxMzk5NDY2MTg=
# 16   85951144  MDEwOlJlcG9zaXRvcnk4NTk1MTE0NA==
# 17   97860064  MDEwOlJlcG9zaXRvcnk5Nzg2MDA2NA==
# 18  111009816  MDEwOlJlcG9zaXRvcnkxMTEwMDk4MTY=
# 19   64460430  MDEwOlJlcG9zaXRvcnk2NDQ2MDQzMA==
# 20   80106272  MDEwOlJlcG9zaXRvcnk4MDEwNjI3Mg==
# 21  154337700  MDEwOlJlcG9zaXRvcnkxNTQzMzc3MDA=
# 22  171431612  MDEwOlJlcG9zaXRvcnkxNzE0MzE2MTI=
# 23  138696932  MDEwOlJlcG9zaXRvcnkxMzg2OTY5MzI=
# 24  122657565  MDEwOlJlcG9zaXRvcnkxMjI2NTc1NjU=
# 25   67062193  MDEwOlJlcG9zaXRvcnk2NzA2MjE5Mw==
# 26   41479576  MDEwOlJlcG9zaXRvcnk0MTQ3OTU3Ng==
# 27  144919503  MDEwOlJlcG9zaXRvcnkxNDQ5MTk1MDM=
# 28   71986993  MDEwOlJlcG9zaXRvcnk3MTk4Njk5Mw==
# 29   90763482  MDEwOlJlcG9zaXRvcnk5MDc2MzQ4Mg==
#
#                                           name  \
# 0                                         2048
# 1                      alfresco-keycloak-theme
# 2                                auth-exercise
# 3                                          bbq
# 4                        bcn-webdev-cheatsheet
# 5                                     bindings
# 6                          broken-link-website
# 7                                   canvas-lms
# 8                               characters-api
# 9                               css-playground
# 10             data-engineering-code-challenge
# 11                          deploy-build-to-s3
# 12                               docker-hackmd
# 13                                   education
# 14                            emerge-hackathon
# 15                       euro-coding-challenge
# 16                      free-programming-books
# 17                                freeCodeCamp
# 18                                   generator
# 19                                      hackmd
# 20                              hackmd-desktop
# 21                             ih-lms-devstack
# 22                               ih-mobile-app
# 23                                     iron.js
# 24                              ironChat---MEX
# 25                            javascript-koans
# 26                    javascriptMessageDecoder
# 27                          lab-hello-ironhack
# 28  lab-javascript-debugging-error-and-js-hint
# 29                            lab-trello-clone
#
#                                             full_name  private  \
# 0                                       ironhack/2048    False
# 1                    ironhack/alfresco-keycloak-theme    False
# 2                              ironhack/auth-exercise    False
# 3                                        ironhack/bbq    False
# 4                      ironhack/bcn-webdev-cheatsheet    False
# 5                                   ironhack/bindings    False
# 6                        ironhack/broken-link-website    False
# 7                                 ironhack/canvas-lms    False
# 8                             ironhack/characters-api    False
# 9                             ironhack/css-playground    False
# 10           ironhack/data-engineering-code-challenge    False
# 11                        ironhack/deploy-build-to-s3    False
# 12                             ironhack/docker-hackmd    False
# 13                                 ironhack/education    False
# 14                          ironhack/emerge-hackathon    False
# 15                     ironhack/euro-coding-challenge    False
# 16                    ironhack/free-programming-books    False
# 17                              ironhack/freeCodeCamp    False
# 18                                 ironhack/generator    False
# 19                                    ironhack/hackmd    False
# 20                            ironhack/hackmd-desktop    False
# 21                           ironhack/ih-lms-devstack    False
# 22                             ironhack/ih-mobile-app    False
# 23                                   ironhack/iron.js    False
# 24                            ironhack/ironChat---MEX    False
# 25                          ironhack/javascript-koans    False
# 26                  ironhack/javascriptMessageDecoder    False
# 27                        ironhack/lab-hello-ironhack    False
# 28  ironhack/lab-javascript-debugging-error-and-js...    False
# 29                          ironhack/lab-trello-clone    False
#
#                                                 owner  \
# 0   {'login': 'ironhack', 'id': 4854004, 'node_id'...
# 1   {'login': 'ironhack', 'id': 4854004, 'node_id'...
# 2   {'login': 'ironhack', 'id': 4854004, 'node_id'...
# 3   {'login': 'ironhack', 'id': 4854004, 'node_id'...
# 4   {'login': 'ironhack', 'id': 4854004, 'node_id'...
# 5   {'login': 'ironhack', 'id': 4854004, 'node_id'...
# 6   {'login': 'ironhack', 'id': 4854004, 'node_id'...
# 7   {'login': 'ironhack', 'id': 4854004, 'node_id'...
# 8   {'login': 'ironhack', 'id': 4854004, 'node_id'...
# 9   {'login': 'ironhack', 'id': 4854004, 'node_id'...
# 10  {'login': 'ironhack', 'id': 4854004, 'node_id'...
# 11  {'login': 'ironhack', 'id': 4854004, 'node_id'...
# 12  {'login': 'ironhack', 'id': 4854004, 'node_id'...
# 13  {'login': 'ironhack', 'id': 4854004, 'node_id'...
# 14  {'login': 'ironhack', 'id': 4854004, 'node_id'...
# 15  {'login': 'ironhack', 'id': 4854004, 'node_id'...
# 16  {'login': 'ironhack', 'id': 4854004, 'node_id'...
# 17  {'login': 'ironhack', 'id': 4854004, 'node_id'...
# 18  {'login': 'ironhack', 'id': 4854004, 'node_id'...
# 19  {'login': 'ironhack', 'id': 4854004, 'node_id'...
# 20  {'login': 'ironhack', 'id': 4854004, 'node_id'...
# 21  {'login': 'ironhack', 'id': 4854004, 'node_id'...
# 22  {'login': 'ironhack', 'id': 4854004, 'node_id'...
# 23  {'login': 'ironhack', 'id': 4854004, 'node_id'...
# 24  {'login': 'ironhack', 'id': 4854004, 'node_id'...
# 25  {'login': 'ironhack', 'id': 4854004, 'node_id'...
# 26  {'login': 'ironhack', 'id': 4854004, 'node_id'...
# 27  {'login': 'ironhack', 'id': 4854004, 'node_id'...
# 28  {'login': 'ironhack', 'id': 4854004, 'node_id'...
# 29  {'login': 'ironhack', 'id': 4854004, 'node_id'...
#
#                                              html_url  \
# 0                    https://github.com/ironhack/2048
# 1   https://github.com/ironhack/alfresco-keycloak-...
# 2           https://github.com/ironhack/auth-exercise
# 3                     https://github.com/ironhack/bbq
# 4   https://github.com/ironhack/bcn-webdev-cheatsheet
# 5                https://github.com/ironhack/bindings
# 6     https://github.com/ironhack/broken-link-website
# 7              https://github.com/ironhack/canvas-lms
# 8          https://github.com/ironhack/characters-api
# 9          https://github.com/ironhack/css-playground
# 10  https://github.com/ironhack/data-engineering-c...
# 11     https://github.com/ironhack/deploy-build-to-s3
# 12          https://github.com/ironhack/docker-hackmd
# 13              https://github.com/ironhack/education
# 14       https://github.com/ironhack/emerge-hackathon
# 15  https://github.com/ironhack/euro-coding-challenge
# 16  https://github.com/ironhack/free-programming-b...
# 17           https://github.com/ironhack/freeCodeCamp
# 18              https://github.com/ironhack/generator
# 19                 https://github.com/ironhack/hackmd
# 20         https://github.com/ironhack/hackmd-desktop
# 21        https://github.com/ironhack/ih-lms-devstack
# 22          https://github.com/ironhack/ih-mobile-app
# 23                https://github.com/ironhack/iron.js
# 24         https://github.com/ironhack/ironChat---MEX
# 25       https://github.com/ironhack/javascript-koans
# 26  https://github.com/ironhack/javascriptMessageD...
# 27     https://github.com/ironhack/lab-hello-ironhack
# 28  https://github.com/ironhack/lab-javascript-deb...
# 29       https://github.com/ironhack/lab-trello-clone
#
#                                           description   fork  \
# 0   A small clone of 1024 (https://play.google.com...   True
# 1   Theme related assets for use in the Identity S...   True
# 2                 Exercise to practice authentication  False
# 3                     W6D5 Final exercise for week 6   False
# 4                                                None  False
# 5                    Various bindings for µWebSockets   True
# 6                                                None   True
# 7                   The open LMS by Instructure, Inc.   True
# 8                           API for movie characters.  False
# 9                     W3D2 Exercise to understand CSS  False
# 10            Ironhack Code Challenge | Data Engineer  False
# 11  Deploy build artifact for a static website to ...   True
# 12                               docker hackmd  image   True
# 13  A place to discover and contribute to educatio...   True
# 14                     The eMerge Americas Hackathon.  False
# 15     Code your landing page in a day with Ironhack!  False
# 16                                               None   True
# 17  The https://freeCodeCamp.com open source codeb...   True
# 18                     Express' application generator   True
# 19  Realtime collaborative markdown notes on all p...   True
# 20  An electron wrapped desktop client for HackMD ...   True
# 21       Get up and running quickly with edX services   True
# 22                                               None  False
# 23             Code for Ironhack Paris' Iron.js event  False
# 24                                               None  False
# 25                                               None  False
# 26  Ironhack: solution of the exercise to practice...   True
# 27                                               None   True
# 28                                               None  False
# 29                                               None   True
#
#                                                   url  ... open_issues_count  \
# 0          https://api.github.com/repos/ironhack/2048  ...                 0
# 1   https://api.github.com/repos/ironhack/alfresco...  ...                 0
# 2   https://api.github.com/repos/ironhack/auth-exe...  ...                 1
# 3           https://api.github.com/repos/ironhack/bbq  ...                 0
# 4   https://api.github.com/repos/ironhack/bcn-webd...  ...                 1
# 5      https://api.github.com/repos/ironhack/bindings  ...                 0
# 6   https://api.github.com/repos/ironhack/broken-l...  ...                 0
# 7    https://api.github.com/repos/ironhack/canvas-lms  ...                 0
# 8   https://api.github.com/repos/ironhack/characte...  ...                 1
# 9   https://api.github.com/repos/ironhack/css-play...  ...                 0
# 10  https://api.github.com/repos/ironhack/data-eng...  ...                 0
# 11  https://api.github.com/repos/ironhack/deploy-b...  ...                 0
# 12  https://api.github.com/repos/ironhack/docker-h...  ...                 0
# 13    https://api.github.com/repos/ironhack/education  ...                 0
# 14  https://api.github.com/repos/ironhack/emerge-h...  ...                 2
# 15  https://api.github.com/repos/ironhack/euro-cod...  ...                 0
# 16  https://api.github.com/repos/ironhack/free-pro...  ...                 0
# 17  https://api.github.com/repos/ironhack/freeCode...  ...                 0
# 18    https://api.github.com/repos/ironhack/generator  ...                 2
# 19       https://api.github.com/repos/ironhack/hackmd  ...                 0
# 20  https://api.github.com/repos/ironhack/hackmd-d...  ...                 0
# 21  https://api.github.com/repos/ironhack/ih-lms-d...  ...                 0
# 22  https://api.github.com/repos/ironhack/ih-mobil...  ...                 0
# 23      https://api.github.com/repos/ironhack/iron.js  ...                 5
# 24  https://api.github.com/repos/ironhack/ironChat...  ...                 0
# 25  https://api.github.com/repos/ironhack/javascri...  ...                 0
# 26  https://api.github.com/repos/ironhack/javascri...  ...                 0
# 27  https://api.github.com/repos/ironhack/lab-hell...  ...                 2
# 28  https://api.github.com/repos/ironhack/lab-java...  ...                 0
# 29  https://api.github.com/repos/ironhack/lab-trel...  ...                 0
#
#                                               license allow_forking  \
# 0   {'key': 'mit', 'name': 'MIT License', 'spdx_id...          True
# 1   {'key': 'apache-2.0', 'name': 'Apache License ...          True
# 2                                                None          True
# 3                                                None          True
# 4                                                None          True
# 5                                                None          True
# 6                                                None          True
# 7   {'key': 'other', 'name': 'Other', 'spdx_id': '...          True
# 8   {'key': 'isc', 'name': 'ISC License', 'spdx_id...          True
# 9                                                None          True
# 10                                               None          True
# 11  {'key': 'mit', 'name': 'MIT License', 'spdx_id...          True
# 12                                               None          True
# 13  {'key': 'other', 'name': 'Other', 'spdx_id': '...          True
# 14                                               None          True
# 15                                               None          True
# 16  {'key': 'unlicense', 'name': 'The Unlicense', ...          True
# 17  {'key': 'other', 'name': 'Other', 'spdx_id': '...          True
# 18  {'key': 'mit', 'name': 'MIT License', 'spdx_id...          True
# 19  {'key': 'mit', 'name': 'MIT License', 'spdx_id...          True
# 20                                               None          True
# 21  {'key': 'agpl-3.0', 'name': 'GNU Affero Genera...          True
# 22                                               None          True
# 23                                               None          True
# 24                                               None          True
# 25                                               None          True
# 26                                               None          True
# 27                                               None          True
# 28                                               None          True
# 29                                               None          True
#
#    is_template topics visibility forks open_issues watchers default_branch
# 0        False     []     public     1           0        0         master
# 1        False     []     public     0           0        0         master
# 2        False     []     public     1           1        0         master
# 3        False     []     public     1           0        0         master
# 4        False     []     public   141           1       70         master
# 5        False     []     public     1           0        0         master
# 6        False     []     public     1           0        0         master
# 7        False     []     public     2           0        0         master
# 8        False     []     public     1           1        1         master
# 9        False     []     public     2           0        0         master
# 10       False     []     public     3           0        5         master
# 11       False     []     public     1           0        0         master
# 12       False     []     public     1           0        0         master
# 13       False     []     public     1           0        0         master
# 14       False     []     public    28           2        4         master
# 15       False     []     public     6           0        0         master
# 16       False     []     public     7           0        1         master
# 17       False     []     public     2           0        1        staging
# 18       False     []     public     9           2        4        develop
# 19       False     []     public     1           0        1         master
# 20       False     []     public     1           0        0         master
# 21       False     []     public     1           0        0         stable
# 22       False     []     public     1           0        1         master
# 23       False     []     public     4           5        1         master
# 24       False     []     public     6           0        2         master
# 25       False     []     public     3           0        0         master
# 26       False     []     public     1           0        0         master
# 27       False     []     public     3           2        0         master
# 28       False     []     public     3           0        0         master
# 29       False     []     public     2           0        0         master
#
# [30 rows x 77 columns]

# %%
#No. of fork?
print(data.fork.value_counts())
# Out:
# True     17
# False    13
# Name: fork, dtype: int64

# %%
#No. of commit?

print(len(data.git_commits_url))
#print(len(data.commits_url))

#flattened_data = pd.json_normalize(results)
#flattened_data
# Out:
# 30

# %%
#languages used?
#for i in data:
#    print(i)
#print(data.language)

l_set=set(i for i in data.language)
print(l_set)
# Out:
# {'Shell', 'FreeMarker', 'Ruby', 'CSS', 'C++', None, 'TypeScript', 'JavaScript', 'HTML', 'TSQL'}
