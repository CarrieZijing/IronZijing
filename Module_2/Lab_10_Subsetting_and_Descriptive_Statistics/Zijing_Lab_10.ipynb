# %% [markdown]
# # Subsetting and Descriptive Stats
#
# ## Before your start:
#    - Remember that you just need to do one of the challenges.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in IronHack's database.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly: enjoy the process!
#
# #### Import all the necessary libraries here:

# %%
# import libraries here
import numpy as np
import pandas as pd 
from scipy import stats

# %% [markdown]
# # Challenge 1
# #### In this challenge we will use the `Temp_States`  dataset.
#
# #### First import it into a dataframe called `temp`.

# %%
# your code here
temp = pd.read_csv('/Users/carrie/IronHack/DAFT_NOV_21_01/module_2/Lab_10_Subsetting_and_Descriptive_Statistics/Temp_States.csv')
temp
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# #### Print `temp`.

# %%
# your code here
print(temp)
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# #### Explore the data types of the *temp* dataframe. What types of data do we have? Comment your result.

# %%
# your code here
temp.dtypes
# Out:
# City            object
# State           object
# Temperature    float64
# dtype: object

# %%
"""
your comments here
answer: we have 2 columns of string dtype, and one column of float dtype
"""
# Out:
# '\nyour comments here\nanswer: we have 2 columns of string dtype, and one column of float dtype\n'

# %% [markdown]
# #### Select the rows where state is New York.

# %%
# your code here
n_y = temp.loc[temp['State']=='New York']
n_y
# Out:
#       City     State  Temperature
# 0      NYC  New York    19.444444
# 1   Albany  New York     9.444444
# 2  Buffalo  New York     3.333333

# %% [markdown]
# #### What is the average temperature of cities in New York?

# %%
# your code here
n_y['Temperature'].mean()
# Out:
# 10.74074074074074

# %% [markdown]
# #### Which states and cities have a temperature above 15 degrees Celsius?

# %%
# your code here
abv_15 = temp.loc[temp['Temperature']> 15]
abv_15
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222
# 5    Treton   New Jersey    22.222222
# 6    Newark   New Jersey    20.000000

# %% [markdown]
# #### Now, return only the cities that have a temperature above 15 degrees Celsius.

# %%
# your code here
abv_15_city = temp.loc[temp['Temperature']> 15]['City'].tolist()
abv_15_city
# Out:
# ['NYC', 'Hartford', 'Treton', 'Newark']

# %% [markdown]
# #### Which cities have a temperature above 15 degrees Celcius and below 20 degrees Celsius?
#
# **Hint**: First, write the condition. Then, select the rows.

# %%
# your code here
filt = (15< temp['Temperature']) & (temp['Temperature'] <20)
temp[filt]
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222

# %% [markdown]
# #### Find the mean and standard deviation of the temperature of each state.

# %%
# your code here
print('mean: ', temp.groupby(temp['State']).mean())
print('\nstd: ', temp.groupby(temp['State']).std())
# Out:
# mean:               Temperature
# State
# Connecticut    15.833333
# New Jersey     21.111111
# New York       10.740741
#
# std:               Temperature
# State
# Connecticut     1.964186
# New Jersey      1.571348
# New York        8.133404

# %% [markdown]
# #  Challenge 2

# %% [markdown]
# #### Load the `employees` dataset into a dataframe. Call the dataframe `employees`.

# %%
# your code here
employees = pd.read_csv('/Users/carrie/IronHack/DAFT_NOV_21_01/module_2/Lab_10_Subsetting_and_Descriptive_Statistics/Employees.csv')
employees
# Out:
#     Department Education      Title      Name  Years  Salary
# 0        Admin    Master  associate     David      4      58
# 1           IT    Master  associate    Thomas      7      45
# 2        Admin    Master  associate     Diana     10      52
# 3        Admin    Master         VP  Manuella     15      33
# 4        Sales    Master    Analyst     Carla      6      38
# ..         ...       ...        ...       ...    ...     ...
# 495      Sales       PhD         VP    Calvin      2     119
# 496         HR    Master    Analyst    Dustin      6      67
# 497      Sales       PhD         VP   Winston     13      93
# 498         IT       PhD    Analyst      Earl     12     108
# 499      Sales    Master    Analyst     Alvin     13      48
#
# [500 rows x 6 columns]

# %% [markdown]
# #### Explore the data types of the `employees` dataframe. Comment your results.

# %%
# your code here
employees.dtypes
# Out:
# Department    object
# Education     object
# Title         object
# Name          object
# Years          int64
# Salary         int64
# dtype: object

# %%
"""
your comments here
4 string dtype columns, 2 integer column
"""
# Out:
# '\nyour comments here\n4 string dtype columns, 2 integer column\n'

# %% [markdown]
# #### What's the average salary in this company?

# %%
# your code here
employees['Salary'].mean()
# Out:
# 73.528

# %% [markdown]
# #### What's the highest salary?

# %%
# your code here
employees['Salary'].max()
# Out:
# 120

# %% [markdown]
# #### What's the lowest salary?

# %%
# your code here
lowest = employees['Salary'].min()
lowest
# Out:
# 30

# %% [markdown]
# #### Who are the employees with the lowest salary?

# %%
# your code here
low = employees['Salary']== lowest
employees[low]['Name'].tolist()
# Out:
# ['Sean', 'Luke', 'Adam', 'Rick', 'Neil', 'Marcel', 'Augustin']

# %% [markdown]
# #### Find all the information about an employee called David.

# %%
# your code here
employees[employees['Name']=='David']
# Out:
#     Department Education      Title   Name  Years  Salary
# 0        Admin    Master  associate  David      4      58
# 124         IT  Bachelor         VP  David      3      31

# %% [markdown]
# #### Could you return only David's salary?

# %%
# your code here
employees[employees['Name']=='David']['Salary']
# Out:
# 0      58
# 124    31
# Name: Salary, dtype: int64

# %% [markdown]
# #### Print all the rows where job title is associate.

# %%
# your code here
#check first if all the 'associate' is uniformed
print(employees['Title'].value_counts())

#very clean, filt the df
employees[employees['Title']=='associate']
# Out:
# Analyst      179
# VP           163
# associate    158
# Name: Title, dtype: int64
#     Department Education      Title      Name  Years  Salary
# 0        Admin    Master  associate     David      4      58
# 1           IT    Master  associate    Thomas      7      45
# 2        Admin    Master  associate     Diana     10      52
# 7           HR    Master  associate     Carol     14      53
# 8        Admin       PhD  associate      Jean      8      50
# ..         ...       ...        ...       ...    ...     ...
# 477         HR       PhD  associate   Phillip     11     113
# 486         IT  Bachelor  associate       Jay     14      58
# 487         HR    Master  associate  Patricia     10     110
# 491      Admin       PhD  associate     Alice      8      37
# 494      Sales  Bachelor  associate   Vanessa     11     118
#
# [158 rows x 6 columns]

# %% [markdown]
# #### Print the first 3 rows of your dataframe.
# **Tip**: There are 2 ways to do it. Do it both ways.

# %%
# Method 1
# your code here
employees.head(3)
# Out:
#   Department Education      Title    Name  Years  Salary
# 0      Admin    Master  associate   David      4      58
# 1         IT    Master  associate  Thomas      7      45
# 2      Admin    Master  associate   Diana     10      52

# %%
# Method 2
# your code here
employees.loc[:2]
# Out:
#   Department Education      Title    Name  Years  Salary
# 0      Admin    Master  associate   David      4      58
# 1         IT    Master  associate  Thomas      7      45
# 2      Admin    Master  associate   Diana     10      52

# %% [markdown]
# #### Find the employees whose title is associate and whose salary is above 55.

# %%
# your code here
asso_55 = (employees['Title']=='associate') & (employees['Salary']>55)
employees[asso_55]
# Out:
#     Department Education      Title      Name  Years  Salary
# 0        Admin    Master  associate     David      4      58
# 9        Admin    Master  associate    Kareem      3     104
# 10       Admin    Master  associate   Cynthia      1     114
# 16       Admin  Bachelor  associate    Shanon      1      99
# 18       Admin  Bachelor  associate     Megan      9      79
# ..         ...       ...        ...       ...    ...     ...
# 476      Admin       PhD  associate      Greg      8      93
# 477         HR       PhD  associate   Phillip     11     113
# 486         IT  Bachelor  associate       Jay     14      58
# 487         HR    Master  associate  Patricia     10     110
# 494      Sales  Bachelor  associate   Vanessa     11     118
#
# [104 rows x 6 columns]

# %% [markdown]
# #### Group the employees by number of years of employment. What are the average salaries in each group?

# %%
# your code here
employees[['Years','Salary']].groupby(employees['Years']).mean()
# Out:
#        Years     Salary
# Years
# 1        1.0  75.863636
# 2        2.0  75.857143
# 3        3.0  74.571429
# 4        4.0  77.129032
# 5        5.0  73.857143
# 6        6.0  72.382353
# 7        7.0  73.840000
# 8        8.0  64.250000
# 9        9.0  76.741935
# 10      10.0  73.351351
# 11      11.0  74.866667
# 12      12.0  73.454545
# 13      13.0  71.935484
# 14      14.0  70.968750
# 15      15.0  69.758621

# %% [markdown]
# ####  What is the average salary per title?

# %%
# your code here
employees[['Title','Salary']].groupby(employees['Title']).mean()
# Out:
#               Salary
# Title
# Analyst    73.703911
# VP         72.907975
# associate  73.968354

# %% [markdown]
# ####  Find the salary quartiles.

# %%
# your code here
employees['Salary'].quantile([0.25,0.5,0.75])
# Out:
# 0.25    50.0
# 0.50    72.0
# 0.75    97.0
# Name: Salary, dtype: float64

# %% [markdown]
# #### Is the mean salary different per gender?

# %%
# your code here
# there is no gender in this dataframe

# %% [markdown]
# #### Find the minimum, mean and maximum of all numeric columns for each company department.

# %%
# your code here
num = employees.select_dtypes(include='int64')
#num
print('max of each numeric column: \n', num.max())
print('\nmin of each numeric column: \n', num.min())
# Out:
# max of each numeric column:
#  Years      15
# Salary    120
# dtype: int64
#
# min of each numeric column:
#  Years      1
# Salary    30
# dtype: int64

# %% [markdown]
# #### Bonus Question:  for each department, compute the difference between the maximum and the minimum salary.
# **Hint**: try using `agg` or `apply` combined with `lambda` functions.

# %%
# your code here

employees[['Department','Salary']].groupby(employees['Department']).agg(lambda x: x.max()-x.min())
# Out:
# /Users/carrie/opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/generic.py:303: FutureWarning: Dropping invalid columns in SeriesGroupBy.agg is deprecated. In a future version, a TypeError will be raised. Before calling .agg, select only columns which should be valid for the aggregating function.
#   results[key] = self.aggregate(func)
#             Salary
# Department
# Admin           90
# HR              89
# IT              90
# Sales           90

# %%
# to double check the result above, very correct!
employees.groupby(employees['Department'])['Salary'].describe()
# Out:
#             count       mean        std   min    25%   50%    75%    max
# Department
# Admin       123.0  76.325203  25.734615  30.0  53.50  78.0  98.00  120.0
# HR          122.0  74.237705  26.522423  30.0  50.25  74.5  96.00  119.0
# IT          134.0  70.671642  27.406101  30.0  46.25  69.0  97.75  120.0
# Sales       121.0  73.132231  27.819340  30.0  49.00  69.0  95.00  120.0

# %% [markdown]
# # Challenge 3
# #### Open the `Orders` dataset. Name your dataset `orders`.

# %%
# your code here
orders = pd.read_csv('/Users/carrie/IronHack/DAFT_NOV_21_01/module_2/Lab_10_Subsetting_and_Descriptive_Statistics/Orders.csv', sep=';', index_col=0)
orders
# Out:
#         InvoiceNo StockCode  year  month  day  hour  \
# 0          536365    85123A  2010     12    3     8
# 1          536365     71053  2010     12    3     8
# 2          536365    84406B  2010     12    3     8
# 3          536365    84029G  2010     12    3     8
# 4          536365    84029E  2010     12    3     8
# ...           ...       ...   ...    ...  ...   ...
# 541904     581587     22613  2011     12    5    12
# 541905     581587     22899  2011     12    5    12
# 541906     581587     23254  2011     12    5    12
# 541907     581587     23255  2011     12    5    12
# 541908     581587     22138  2011     12    5    12
#
#                                 Description  Quantity          InvoiceDate  \
# 0        white hanging heart t-light holder         6   2010-12-01 8:26:00
# 1                       white metal lantern         6   2010-12-01 8:26:00
# 2            cream cupid hearts coat hanger         8   2010-12-01 8:26:00
# ...

# %% [markdown]
# #### Explore your dataset by looking at the data types and summary statistics. Comment your results.

# %%
# your code here
orders.dtypes
# Out:
# InvoiceNo        int64
# StockCode       object
# year             int64
# month            int64
# day              int64
# hour             int64
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice       object
# CustomerID       int64
# Country         object
# amount_spent    object
# dtype: object

# %%
"""
your comments here
7 integer cols, in which amount_spent, unitprice need to be changed into float dtype
"""
#orders.apply(lambda x: x.str.replace(',','.'))

order = orders.replace(',','.',regex=True)

order[['UnitPrice', 'amount_spent']] = order[['UnitPrice', 'amount_spent']].astype(np.float64)

# %% [markdown]
# ####  What is the average purchase price?

# %%
# your code here
order['amount_spent'].mean()
# Out:
# 22.39474850474768

# %% [markdown]
# #### What are the highest and lowest purchase prices?

# %%
# your code here
p_min = order['amount_spent'].min()
p_max = order['amount_spent'].max()

print('lowest purchase price is: ',p_min, '\nhighest purchase price is: ',p_max)
# Out:
# lowest purchase price is:  0.0
# highest purchase price is:  168469.6

# %% [markdown]
# #### Select all the customers from Spain.
# **Hint**: Remember that you are not asked to find orders from Spain but customers. A customer might have more than one order associated.

# %%
# your code here
#find the exact string written in the Country for Spain
order['Country'].value_counts()

filt = order['Country'] == 'Spain'
sp_client = order[filt]['CustomerID'].unique().tolist()
print('customers from Spaincustomer id:', sp_client)
# Out:
# customers from Spaincustomer id: [12557, 17097, 12540, 12551, 12484, 12539, 12510, 12421, 12502, 12462, 12507, 12541, 12547, 12597, 12545, 12596, 12354, 12417, 12455, 12450, 12548, 12556, 12550, 12546, 12454, 12448, 12544, 12538, 12445, 12442]

# %% [markdown]
# #### How many customers do we have in Spain?

# %%
# your code here
len(sp_client)
# Out:
# 30

# %% [markdown]
# #### Select all the customers who have bought more than 50 items.
# **Hint**: Remember that you are not asked to find orders with more than 50 items but customers who bought more than 50 items. A customer with two orders of 30 items each should appear in the selection.

# %%
# your code here
quantity_client = order[['CustomerID','Quantity']].groupby(order['CustomerID']).sum()
quantity_client[quantity_client['Quantity'] > 50]
# Out:
#             CustomerID  Quantity
# CustomerID
# 12346            12346     74215
# 12347          2247154      2458
# 12348           382788      2341
# 12349           901477       631
# 12350           209950       197
# ...                ...       ...
# 18278           164502        66
# 18281           127967        54
# 18282           219384       103
# 18283         13821948      1397
# 18287          1280090      1586
#
# [4091 rows x 2 columns]

# %% [markdown]
# #### Select orders from Spain that include more than 50 items.

# %%
# your code here
sp_50 = order[(order['Country'] == 'Spain')&(order['Quantity']> 50)]
sp_50

#double check the result with value_counts()
#sp_50[['Country','Quantity']].value_counts()
# Out:
#         InvoiceNo StockCode  year  month  day  hour  \
# 6421       536944     22383  2010     12    5    12
# 6422       536944     22384  2010     12    5    12
# 6423       536944     20727  2010     12    5    12
# 6424       536944     20725  2010     12    5    12
# 6425       536944     20728  2010     12    5    12
# 52416      540785    84997B  2011      1    2    11
# 52417      540785    84997D  2011      1    2    11
# 52418      540785    84997C  2011      1    2    11
# 52419      540785    84997A  2011      1    2    11
# 136767     547972     22383  2011      3    1    16
# 136768     547972     22384  2011      3    1    16
# 136771     547972     20728  2011      3    1    16
# 248797     558871     22384  2011      7    1    13
# 248798     558871     20727  2011      7    1    13
# 248799     558871     20725  2011      7    1    13
# 248800     558871     20728  2011      7    1    13
# 248801     558871    84997B  2011      7    1    13
# ...

# %% [markdown]
# #### Select all free orders.

# %%
# your code here
order[order['amount_spent']==0]
# Out:
#         InvoiceNo StockCode  year  month  day  hour  \
# 9302       537197     22841  2010     12    7    14
# 33576      539263     22580  2010     12    4    14
# 40089      539722     22423  2010     12    2    13
# 47068      540372     22090  2011      1    4    16
# 47070      540372     22553  2011      1    4    16
# 56674      541109     22168  2011      1    4    15
# 86789      543599    84535B  2011      2    4    13
# 130188     547417     22062  2011      3    3    10
# 139453     548318     22055  2011      3    3    12
# 145208     548871     22162  2011      4    1    14
# 157042     550188     22636  2011      4    4    18
# 187613     553000     47566  2011      5    4    15
# 198383     554037     22619  2011      5    5    14
# 279324     561284     22167  2011      7    2    12
# 282912     561669     22960  2011      7    4    17
# 285657     561916         M  2011      8    1    11
# 298054     562973     23157  2011      8    4    11
# ...

# %% [markdown]
# #### Select all orders whose description starts with `lunch bag`.
# **Hint**: use string functions.

# %%
# your code here
lunch = order[order['Description'].str.startswith('lunch bag')]
lunch
#double check the result using value_counts
#lunch['Description'].value_counts()
# Out:
#         InvoiceNo StockCode  year  month  day  hour  \
# 93         536378     20725  2010     12    3     9
# 174        536385     22662  2010     12    3     9
# 363        536401     22662  2010     12    3    11
# 368        536401     20725  2010     12    3    11
# 369        536401     22382  2010     12    3    11
# ...           ...       ...   ...    ...  ...   ...
# 540436     581486     23207  2011     12    5     9
# 541695     581538     20727  2011     12    5    11
# 541696     581538     20725  2011     12    5    11
# 541862     581581     23681  2011     12    5    12
# 541865     581583     20725  2011     12    5    12
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 93          lunch bag red retrospot        10   2010-12-01 9:37:00       1.65
# 174     lunch bag dolly girl design        10   2010-12-01 9:56:00       1.65
# 363     lunch bag dolly girl design         1  2010-12-01 11:21:00       1.65
# ...

# %% [markdown]
# #### Select all `lunch bag` orders made in 2011.

# %%
# your code here
lunch[lunch['year']==2011]
# Out:
#         InvoiceNo StockCode  year  month  day  hour  \
# 42678      540015     20725  2011      1    2    11
# 42679      540015     20726  2011      1    2    11
# 42851      540023     22382  2011      1    2    12
# 42852      540023     20726  2011      1    2    12
# 43616      540098     22384  2011      1    2    15
# ...           ...       ...   ...    ...  ...   ...
# 540436     581486     23207  2011     12    5     9
# 541695     581538     20727  2011     12    5    11
# 541696     581538     20725  2011     12    5    11
# 541862     581581     23681  2011     12    5    12
# 541865     581583     20725  2011     12    5    12
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 42678       lunch bag red retrospot        10  2011-01-04 11:40:00       1.65
# 42679            lunch bag woodland        10  2011-01-04 11:40:00       1.65
# 42851     lunch bag spaceboy design         2  2011-01-04 12:58:00       1.65
# ...

# %% [markdown]
# #### Show the frequency distribution of the amount spent in Spain.

# %%
# your code here

order[order['Country']=='Spain']['amount_spent'].value_counts()
# Out:
# 15.00     186
# 17.70     122
# 19.80      99
# 17.40      86
# 10.20      76
#          ...
# 2.60        1
# 5.85        1
# 27.00       1
# 41.60       1
# 109.50      1
# Name: amount_spent, Length: 309, dtype: int64

# %% [markdown]
# #### Select all orders made in the month of August.

# %%
# your code here
aug = order[order['month']==8]
aug
# Out:
#         InvoiceNo StockCode  year  month  day  hour  \
# 285421     561904     22075  2011      8    1     8
# 285422     561904    85049E  2011      8    1     8
# 285423     561905     21385  2011      8    1     9
# 285424     561905    84970L  2011      8    1     9
# 285425     561905    84970S  2011      8    1     9
# ...           ...       ...   ...    ...  ...   ...
# 320688     565067     22644  2011      8    3    17
# 320689     565067     22645  2011      8    3    17
# 320690     565067     22637  2011      8    3    17
# 320691     565067     22646  2011      8    3    17
# 320692     565067     22741  2011      8    3    17
#
#                                 Description  Quantity          InvoiceDate  \
# 285421          6 ribbons elegant christmas        96   2011-08-01 8:30:00
# 285422            scandinavian reds ribbons       156   2011-08-01 8:30:00
# 285423      ivory hanging decoration  heart        24   2011-08-01 9:31:00
# ...

# %% [markdown]
# #### Find the number of orders made by each country in the month of August.
# **Hint**: Use value_counts().

# %%
# your code here
aug['Country'].value_counts()
# Out:
# United Kingdom     23105
# Germany              795
# EIRE                 593
# France               569
# Netherlands          280
# Switzerland          267
# Spain                252
# Belgium              194
# Israel               171
# Channel Islands      140
# Australia            107
# Italy                 95
# Austria               88
# Norway                77
# Finland               61
# Malta                 55
# Portugal              41
# Sweden                40
# Unspecified           23
# Iceland               22
# Poland                17
# Denmark               16
# Canada                 5
# Name: Country, dtype: int64

# %% [markdown]
# #### What's the  average amount of money spent by country?

# %%
# your code here
order[['Country','amount_spent']].groupby(['Country']).mean()
# Out:
#                       amount_spent
# Country
# Australia               116.895620
# Austria                  25.624824
# Bahrain                  32.258824
# Belgium                  20.283772
# Brazil                   35.737500
# Canada                   24.280662
# Channel Islands          27.340160
# Cyprus                   22.134169
# Czech Republic           33.069600
# Denmark                  49.882474
# EIRE                     36.687745
# European Community       21.670833
# Finland                  32.913985
# France                   25.056827
# Germany                  25.311562
# Greece                   32.831172
# Iceland                  23.681319
# Israel                   29.119718
# Italy                    23.064960
# Japan                   116.561900
# Lebanon                  37.641778
# Lithuania                47.458857
# Malta                    24.335625
# Netherlands             120.798282
# Norway                   33.736418
# ...

# %% [markdown]
# #### What's the most expensive item?

# %%
# your code here
order['UnitPrice'].max()
# Out:
# 8142.75

# %% [markdown]
# #### What is the average amount spent per year?

# %%
# your code here
order[['year','amount_spent']].groupby(['year']).mean()
# Out:
#       amount_spent
# year
# 2010     21.892733
# 2011     22.430074
